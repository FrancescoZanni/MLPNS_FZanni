# %% [markdown]
# <a href="https://colab.research.google.com/github/FrancescoZanni/MLPNS_FZanni/blob/main/vis/VisualizationExcercize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pylab as pl
import scipy.io
import plotly.express as px
import os
import json 
# %pylab inline

from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Mounted at /content/drive/

# %%
cd drive/MyDrive/vis
# Out:
# /content/drive/MyDrive/vis

# %%
ls
# Out:
#  bitcoin-and-ethereum-prices-from-start-to-2023.zip
# 'Bitcoin prices.csv'
#  Data.mat
# 'Ethereum prices.csv'
#  gap.m
# 'List of world cities by population density.csv'
#  list-of-world-cities-by-population-density.zip
#  Meteorite_Landings.csv
#  meteorite-landings.zip

# %%
data = scipy.io.loadmat('Data.mat')
data["lambda"]=[0.2,1,3,10]
data["ris"]=[0,0.3572,0.8551,1.7763,3.2976]

# %%
fig,ax = plt.subplots(1,1,figsize=(9,5))
ax.plot(data["x"].T,data["yL02"].T,label="fit $\lambda$=0.2",linestyle='dashed',color='#FF5995',alpha=0.4)
ax.plot((data["a"]**2).T,data["E0L02"].T,label="sim $\lambda$=0.2",color='#FF5995', marker='.',markersize=8,linewidth=0)


ax.plot(data["x"].T,data["yL1"].T,label="fit $\lambda=1$",linestyle='dashed',color='#1E88E5',alpha=0.4)
ax.plot((data["a"]**2).T,data["E0L1"].T,label="sim $\lambda$=1",color='#1E88E5', marker='.',markersize=8,linewidth=0)

ax.plot(data["x"].T,data["yL3"].T,label="fit $\lambda=3$",linestyle='dashed',color='#FFC107',alpha=0.4)
ax.plot((data["a"]**2).T,data["E0L3"].T,label="sim $\lambda$=3",color='#FFC107', marker='.',markersize=8,linewidth=0)

ax.plot(data["x"].T,data["yL10"].T,label="fit $\lambda=10$",linestyle='dashed',color='#004D40',alpha=0.4)
ax.plot((data["a"]**2).T,data["E0L10"].T,label="sim $\lambda$=10",color='#004D40', marker='.',markersize=8,linewidth=0)




ax.legend()
ax.set_title("Stima del livello fondamentale E0 ")
ax.set_xlabel("$a^2$")
ax.set_ylabel("E0")
ax.set_xlim(0,1.03)
ax.set_ylim(-0,3.6)
ax.set_yticks(data["ris"])

txt="Calcolo dell'energia del libello fondamentale per un sistema soggetto ad un potenziale a doppia buca \n$\lambda(x^2-x_0^2)^2$ al variare del parametro $\lambda$. \nL'estrapolazione dell'intercetta da un fit quadratico fornisce la migliore stima"
fig.text(.130,-.1,txt);
